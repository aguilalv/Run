# %%
import pandas as pd
import os
import sys
sys.path.append('C:\\Users\\aaagui\\Documents\\PyProjects\\Run\\Run')
import activities
import TCX

# %%
run = activities.run(TCX.parse("C:\\Users\\aaagui\\Documents\\PyProjects\\Run\\data\\STRun2.tcx"))
df = run.df
df.head(5)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>timestamp</th>
#       <th>lap</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>altitude</th>
#       <th>distance</th>
#       <th>heartrate</th>
#       <th>cadence</th>
#       <th>power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2016-12-19 12:25:09+00:00</td>
#       <td>1</td>
#       <td>39.449821</td>
#       <td>-0.392466</td>
#       <td>16.1</td>
#       <td>0.00</td>
#       <td>85.0</td>
#       <td>58.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2016-12-19 12:25:10+00:00</td>
#       <td>1</td>
#       <td>39.449814</td>
#       <td>-0.392470</td>
#       <td>16.1</td>
#       <td>0.93</td>
#       <td>85.0</td>
#       <td>57.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2016-12-19 12:25:11+00:00</td>
# ...

# %%
# Calculate speed in km/h
df['speed'] = (df['distance'] - df['distance'].shift(1)) * 3.6

# %%
#calculate pace in seconds / Km
df['pace'] = 3600 / df['speed']

# %%
# calculate slope in % (100 * rise / run)
((df['altitude'] - df['altitude'].shift(i)) / (df['distance'] - df['distance'].shift(i)))*100
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...
